# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import metrics
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objs as go
import scipy.cluster.hierarchy as sch

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
num_clusters=8
kmeans=KMeans(n_clusters=num_clusters)
kmeans.fit(X)

score = metrics.silhouette_score(X,kmeans.labels_,metric='euclidean',sample_size=len(X))
print('\n Numero de clusters =',num_clusters)
print('Silhouette Score =',score)
# Out:
#  Numero de clusters = 8
# Silhouette Score = 0.5369954815914457

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
num_clusters=5
kmeans=KMeans(n_clusters=num_clusters)
kmeans.fit(X)

score = metrics.silhouette_score(X,kmeans.labels_,metric='euclidean',sample_size=len(X))
print('\n Numero de clusters =',num_clusters)
print('Silhouette Score =',score)
# Out:
#  Numero de clusters = 5
# Silhouette Score = 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
num_clusters=3
kmeans=KMeans(n_clusters=num_clusters)
kmeans.fit(X)

score = metrics.silhouette_score(X,kmeans.labels_,metric='euclidean',sample_size=len(X))
print('\n Numero de clusters =',num_clusters)
print('Silhouette Score =',score)
# Out:
#  Numero de clusters = 3
# Silhouette Score = 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
Sum_of_squared_distances = []
K = range(1,10)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(X)
    Sum_of_squared_distances.append(km.inertia_)
plt.figure(figsize=(20,5))
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
plt.figure(figsize=(20,10))
dendograma= sch.dendrogram(sch.linkage(X,method='ward'))


num_clusters = range(1,10)

ac=AgglomerativeClustering(n_clusters=num_clusters)
ac.fit(cluster_scaled)
#Pasamos nuestro dataset, nuestros clusters, nuestra metrida/meduida,tamaño de la muestra para el score
score = metrics.silhouette_score(X,ac.labels_,metric='euclidean',sample_size=len(X))
print('\n Numero de clusters =',num_clusters)
print('Silhouette Score =',score)

# %%
from sklearn.cluster import AgglomerativeClustering
scores=[]
inertias= []
values = np.arange(2,10)

for num_clusters in values:
  ac=AgglomerativeClustering(n_clusters=num_clusters)
  ac.fit(X)
  #Pasamos nuestro dataset, nuestros clusters, nuestra metrida/meduida,tamaño de la muestra para el score
  score = metrics.silhouette_score(X,ac.labels_,metric='euclidean',sample_size=len(X))
  print('\n Numero de clusters =',num_clusters)
  print('Silhouette Score =',score)
  scores.append(score)

  #Queremos una puntuación (score) alta, es decir entre más cerca a 1 mejor.
  #Indicaría es que hay una distancia pequeña promedio entre cada miembro del grupo
  #Entre cada cluster va a existir una considerable distancia
# Out:
#  Numero de clusters = 2
# Silhouette Score = 0.6587292996216916
#
#  Numero de clusters = 3
# Silhouette Score = 0.5644796401732073
#
#  Numero de clusters = 4
# Silhouette Score = 0.5606726948394272
#
#  Numero de clusters = 5
# Silhouette Score = 0.5074843044233799
#
#  Numero de clusters = 6
# Silhouette Score = 0.5270523448339737
#
#  Numero de clusters = 7
# Silhouette Score = 0.5369215536550145
#
#  Numero de clusters = 8
# Silhouette Score = 0.5299175684221904
#
#  Numero de clusters = 9
# Silhouette Score = 0.5307062601720857

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.
